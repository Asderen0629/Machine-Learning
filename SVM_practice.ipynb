# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from IPython.display import display
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# 匯入資料 「防火牆判斷是否要讓網路封包通過」
df = pd.read_csv("internet-firewall-dataset.csv")
df.head()
# Out:
#    Source Port  Destination Port  NAT Source Port  NAT Destination Port  \
# 0        57222                53            54587                    53
# 1        56258              3389            56258                  3389
# 2         6881             50321            43265                 50321
# 3        50553              3389            50553                  3389
# 4        50002               443            45848                   443
#
#   Action  Bytes  Bytes Sent  Bytes Received  Packets  Elapsed Time (sec)  \
# 0  allow    177          94              83        2                  30
# 1  allow   4768        1600            3168       19                  17
# 2  allow    238         118             120        2                1199
# 3  allow   3327        1438            1889       15                  17
# 4  allow  25358        6778           18580       31                  16
#
#    pkts_sent  pkts_received
# 0          1              1
# 1         10              9
# 2          1              1
# 3          8              7
# 4         13             18

# %%
# 檢查資料
print ("空值：", df.isnull().values.sum())
print ("資料筆數：", df.shape)
print ("資料欄位名稱：\n", df.keys())
print ("第一筆資料：\n", df.iloc[0,::])
print ("資料型態：\n", df.dtypes)
# Out:
# 空值： 0
# 資料筆數： (65532, 12)
# 資料欄位名稱：
#  Index(['Source Port', 'Destination Port', 'NAT Source Port',
#        'NAT Destination Port', 'Action', 'Bytes', 'Bytes Sent',
#        'Bytes Received', 'Packets', 'Elapsed Time (sec)', 'pkts_sent',
#        'pkts_received'],
#       dtype='object')
# 第一筆資料：
#  Source Port             57222
# Destination Port           53
# NAT Source Port         54587
# NAT Destination Port       53
# Action                  allow
# Bytes                     177
# Bytes Sent                 94
# Bytes Received             83
# Packets                     2
# Elapsed Time (sec)         30
# pkts_sent                   1
# pkts_received               1
# Name: 0, dtype: object
# 資料型態：
#  Source Port              int64
# Destination Port         int64
# NAT Source Port          int64
# NAT Destination Port     int64
# Action                  object
# Bytes                    int64
# Bytes Sent               int64
# Bytes Received           int64
# Packets                  int64
# Elapsed Time (sec)       int64
# pkts_sent                int64
# pkts_received            int64
# dtype: object

# %%
# 共線性檢查-相關係數
display(df.corr().style.applymap(lambda x: 'color :red ' if 1 > x > 0.7 else  'color : black'))
# 刪除相關性高的自變數
df2 = df.drop(columns=['Bytes','Packets','pkts_sent','pkts_received'])
display(df2.corr().style.applymap(lambda x: 'color :red ' if 1 > x > 0.7 else  'color : black'))
# Out:
# <style type="text/css">
# #T_8617d_row0_col0, #T_8617d_row0_col1, #T_8617d_row0_col2, #T_8617d_row0_col3, #T_8617d_row0_col4, #T_8617d_row0_col5, #T_8617d_row0_col6, #T_8617d_row0_col7, #T_8617d_row0_col8, #T_8617d_row0_col9, #T_8617d_row0_col10, #T_8617d_row1_col0, #T_8617d_row1_col1, #T_8617d_row1_col2, #T_8617d_row1_col3, #T_8617d_row1_col4, #T_8617d_row1_col5, #T_8617d_row1_col6, #T_8617d_row1_col7, #T_8617d_row1_col8, #T_8617d_row1_col9, #T_8617d_row1_col10, #T_8617d_row2_col0, #T_8617d_row2_col1, #T_8617d_row2_col2, #T_8617d_row2_col3, #T_8617d_row2_col4, #T_8617d_row2_col5, #T_8617d_row2_col6, #T_8617d_row2_col7, #T_8617d_row2_col8, #T_8617d_row2_col9, #T_8617d_row2_col10, #T_8617d_row3_col0, #T_8617d_row3_col1, #T_8617d_row3_col2, #T_8617d_row3_col3, #T_8617d_row3_col4, #T_8617d_row3_col5, #T_8617d_row3_col6, #T_8617d_row3_col7, #T_8617d_row3_col8, #T_8617d_row3_col9, #T_8617d_row3_col10, #T_8617d_row4_col0, #T_8617d_row4_col1, #T_8617d_row4_col2, #T_8617d_row4_col3, #T_8617d_row4_col4, #T_8617d_row4_col8, #T_8617d_row5_col0, #T_8617d_row5_col1, #T_8617d_row5_col2, #T_8617d_row5_col3, #T_8617d_row5_col5, #T_8617d_row5_col6, #T_8617d_row5_col8, #T_8617d_row5_col10, #T_8617d_row6_col0, #T_8617d_row6_col1, #T_8617d_row6_col2, #T_8617d_row6_col3, #T_8617d_row6_col5, #T_8617d_row6_col6, #T_8617d_row6_col8, #T_8617d_row6_col9, #T_8617d_row7_col0, #T_8617d_row7_col1, #T_8617d_row7_col2, #T_8617d_row7_col3, #T_8617d_row7_col7, #T_8617d_row7_col8, #T_8617d_row8_col0, #T_8617d_row8_col1, #T_8617d_row8_col2, #T_8617d_row8_col3, #T_8617d_row8_col4, #T_8617d_row8_col5, #T_8617d_row8_col6, #T_8617d_row8_col7, #T_8617d_row8_col8, #T_8617d_row8_col9, #T_8617d_row8_col10, #T_8617d_row9_col0, #T_8617d_row9_col1, #T_8617d_row9_col2, #T_8617d_row9_col3, #T_8617d_row9_col6, #T_8617d_row9_col8, #T_8617d_row9_col9, #T_8617d_row10_col0, #T_8617d_row10_col1, #T_8617d_row10_col2, #T_8617d_row10_col3, #T_8617d_row10_col5, #T_8617d_row10_col8, #T_8617d_row10_col10 {
#   color: black;
# }
# #T_8617d_row4_col5, #T_8617d_row4_col6, #T_8617d_row4_col7, #T_8617d_row4_col9, #T_8617d_row4_col10, #T_8617d_row5_col4, #T_8617d_row5_col7, #T_8617d_row5_col9, #T_8617d_row6_col4, #T_8617d_row6_col7, #T_8617d_row6_col10, #T_8617d_row7_col4, #T_8617d_row7_col5, #T_8617d_row7_col6, #T_8617d_row7_col9, #T_8617d_row7_col10, #T_8617d_row9_col4, #T_8617d_row9_col5, #T_8617d_row9_col7, #T_8617d_row9_col10, #T_8617d_row10_col4, #T_8617d_row10_col6, #T_8617d_row10_col7, #T_8617d_row10_col9 {
#   color: red;
# }
# </style>
# <table id="T_8617d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8617d_level0_col0" class="col_heading level0 col0" >Source Port</th>
#       <th id="T_8617d_level0_col1" class="col_heading level0 col1" >Destination Port</th>
#       <th id="T_8617d_level0_col2" class="col_heading level0 col2" >NAT Source Port</th>
#       <th id="T_8617d_level0_col3" class="col_heading level0 col3" >NAT Destination Port</th>
#       <th id="T_8617d_level0_col4" class="col_heading level0 col4" >Bytes</th>
#       <th id="T_8617d_level0_col5" class="col_heading level0 col5" >Bytes Sent</th>
#       <th id="T_8617d_level0_col6" class="col_heading level0 col6" >Bytes Received</th>
#       <th id="T_8617d_level0_col7" class="col_heading level0 col7" >Packets</th>
#       <th id="T_8617d_level0_col8" class="col_heading level0 col8" >Elapsed Time (sec)</th>
#       <th id="T_8617d_level0_col9" class="col_heading level0 col9" >pkts_sent</th>
#       <th id="T_8617d_level0_col10" class="col_heading level0 col10" >pkts_received</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8617d_level0_row0" class="row_heading level0 row0" >Source Port</th>
#       <td id="T_8617d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_8617d_row0_col1" class="data row0 col1" >-0.332246</td>
#       <td id="T_8617d_row0_col2" class="data row0 col2" >0.145391</td>
#       <td id="T_8617d_row0_col3" class="data row0 col3" >-0.024843</td>
#       <td id="T_8617d_row0_col4" class="data row0 col4" >0.000221</td>
#       <td id="T_8617d_row0_col5" class="data row0 col5" >-0.000931</td>
#       <td id="T_8617d_row0_col6" class="data row0 col6" >0.001950</td>
#       <td id="T_8617d_row0_col7" class="data row0 col7" >-0.001742</td>
#       <td id="T_8617d_row0_col8" class="data row0 col8" >-0.046515</td>
#       <td id="T_8617d_row0_col9" class="data row0 col9" >-0.001422</td>
#       <td id="T_8617d_row0_col10" class="data row0 col10" >-0.001962</td>
#     </tr>
#     <tr>
#       <th id="T_8617d_level0_row1" class="row_heading level0 row1" >Destination Port</th>
#       <td id="T_8617d_row1_col0" class="data row1 col0" >-0.332246</td>
#       <td id="T_8617d_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_8617d_row1_col2" class="data row1 col2" >-0.281676</td>
#       <td id="T_8617d_row1_col3" class="data row1 col3" >0.410042</td>
#       <td id="T_8617d_row1_col4" class="data row1 col4" >-0.005297</td>
#       <td id="T_8617d_row1_col5" class="data row1 col5" >0.001675</td>
#       <td id="T_8617d_row1_col6" class="data row1 col6" >-0.014684</td>
#       <td id="T_8617d_row1_col7" class="data row1 col7" >-0.006063</td>
#       <td id="T_8617d_row1_col8" class="data row1 col8" >0.023537</td>
#       <td id="T_8617d_row1_col9" class="data row1 col9" >-0.002134</td>
#       <td id="T_8617d_row1_col10" class="data row1 col10" >-0.010909</td>
#     </tr>
#     <tr>
#       <th id="T_8617d_level0_row2" class="row_heading level0 row2" >NAT Source Port</th>
#       <td id="T_8617d_row2_col0" class="data row2 col0" >0.145391</td>
#       <td id="T_8617d_row2_col1" class="data row2 col1" >-0.281676</td>
#       <td id="T_8617d_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_8617d_row2_col3" class="data row2 col3" >0.178435</td>
#       <td id="T_8617d_row2_col4" class="data row2 col4" >0.010659</td>
#       <td id="T_8617d_row2_col5" class="data row2 col5" >0.002242</td>
#       <td id="T_8617d_row2_col6" class="data row2 col6" >0.020827</td>
#       <td id="T_8617d_row2_col7" class="data row2 col7" >0.012633</td>
#       <td id="T_8617d_row2_col8" class="data row2 col8" >0.141485</td>
#       <td id="T_8617d_row2_col9" class="data row2 col9" >0.007180</td>
#       <td id="T_8617d_row2_col10" class="data row2 col10" >0.018772</td>
#     </tr>
#     <tr>
#       <th id="T_8617d_level0_row3" class="row_heading level0 row3" >NAT Destination Port</th>
#       <td id="T_8617d_row3_col0" class="data row3 col0" >-0.024843</td>
#       <td id="T_8617d_row3_col1" class="data row3 col1" >0.410042</td>
#       <td id="T_8617d_row3_col2" class="data row3 col2" >0.178435</td>
#       <td id="T_8617d_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_8617d_row3_col4" class="data row3 col4" >0.003975</td>
#       <td id="T_8617d_row3_col5" class="data row3 col5" >0.007904</td>
#       <td id="T_8617d_row3_col6" class="data row3 col6" >-0.003216</td>
#       <td id="T_8617d_row3_col7" class="data row3 col7" >0.004605</td>
#       <td id="T_8617d_row3_col8" class="data row3 col8" >0.219776</td>
#       <td id="T_8617d_row3_col9" class="data row3 col9" >0.006136</td>
#       <td id="T_8617d_row3_col10" class="data row3 col10" >0.001747</td>
#     </tr>
#     <tr>
#       <th id="T_8617d_level0_row4" class="row_heading level0 row4" >Bytes</th>
#       <td id="T_8617d_row4_col0" class="data row4 col0" >0.000221</td>
#       <td id="T_8617d_row4_col1" class="data row4 col1" >-0.005297</td>
#       <td id="T_8617d_row4_col2" class="data row4 col2" >0.010659</td>
#       <td id="T_8617d_row4_col3" class="data row4 col3" >0.003975</td>
#       <td id="T_8617d_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_8617d_row4_col5" class="data row4 col5" >0.933462</td>
#       <td id="T_8617d_row4_col6" class="data row4 col6" >0.830225</td>
#       <td id="T_8617d_row4_col7" class="data row4 col7" >0.974379</td>
#       <td id="T_8617d_row4_col8" class="data row4 col8" >0.148834</td>
#       <td id="T_8617d_row4_col9" class="data row4 col9" >0.966548</td>
#       <td id="T_8617d_row4_col10" clas
# <style type="text/css">
# #T_b50d8_row0_col0, #T_b50d8_row0_col1, #T_b50d8_row0_col2, #T_b50d8_row0_col3, #T_b50d8_row0_col4, #T_b50d8_row0_col5, #T_b50d8_row0_col6, #T_b50d8_row1_col0, #T_b50d8_row1_col1, #T_b50d8_row1_col2, #T_b50d8_row1_col3, #T_b50d8_row1_col4, #T_b50d8_row1_col5, #T_b50d8_row1_col6, #T_b50d8_row2_col0, #T_b50d8_row2_col1, #T_b50d8_row2_col2, #T_b50d8_row2_col3, #T_b50d8_row2_col4, #T_b50d8_row2_col5, #T_b50d8_row2_col6, #T_b50d8_row3_col0, #T_b50d8_row3_col1, #T_b50d8_row3_col2, #T_b50d8_row3_col3, #T_b50d8_row3_col4, #T_b50d8_row3_col5, #T_b50d8_row3_col6, #T_b50d8_row4_col0, #T_b50d8_row4_col1, #T_b50d8_row4_col2, #T_b50d8_row4_col3, #T_b50d8_row4_col4, #T_b50d8_row4_col5, #T_b50d8_row4_col6, #T_b50d8_row5_col0, #T_b50d8_row5_col1, #T_b50d8_row5_col2, #T_b50d8_row5_col3, #T_b50d8_row5_col4, #T_b50d8_row5_col5, #T_b50d8_row5_col6, #T_b50d8_row6_col0, #T_b50d8_row6_col1, #T_b50d8_row6_col2, #T_b50d8_row6_col3, #T_b50d8_row6_col4, #T_b50d8_row6_col5, #T_b50d8_row6_col6 {
#   color: black;
# }
# </style>
# <table id="T_b50d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b50d8_level0_col0" class="col_heading level0 col0" >Source Port</th>
#       <th id="T_b50d8_level0_col1" class="col_heading level0 col1" >Destination Port</th>
#       <th id="T_b50d8_level0_col2" class="col_heading level0 col2" >NAT Source Port</th>
#       <th id="T_b50d8_level0_col3" class="col_heading level0 col3" >NAT Destination Port</th>
#       <th id="T_b50d8_level0_col4" class="col_heading level0 col4" >Bytes Sent</th>
#       <th id="T_b50d8_level0_col5" class="col_heading level0 col5" >Bytes Received</th>
#       <th id="T_b50d8_level0_col6" class="col_heading level0 col6" >Elapsed Time (sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b50d8_level0_row0" class="row_heading level0 row0" >Source Port</th>
#       <td id="T_b50d8_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b50d8_row0_col1" class="data row0 col1" >-0.332246</td>
#       <td id="T_b50d8_row0_col2" class="data row0 col2" >0.145391</td>
#       <td id="T_b50d8_row0_col3" class="data row0 col3" >-0.024843</td>
#       <td id="T_b50d8_row0_col4" class="data row0 col4" >-0.000931</td>
#       <td id="T_b50d8_row0_col5" class="data row0 col5" >0.001950</td>
#       <td id="T_b50d8_row0_col6" class="data row0 col6" >-0.046515</td>
#     </tr>
#     <tr>
#       <th id="T_b50d8_level0_row1" class="row_heading level0 row1" >Destination Port</th>
#       <td id="T_b50d8_row1_col0" class="data row1 col0" >-0.332246</td>
#       <td id="T_b50d8_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b50d8_row1_col2" class="data row1 col2" >-0.281676</td>
#       <td id="T_b50d8_row1_col3" class="data row1 col3" >0.410042</td>
#       <td id="T_b50d8_row1_col4" class="data row1 col4" >0.001675</td>
#       <td id="T_b50d8_row1_col5" class="data row1 col5" >-0.014684</td>
#       <td id="T_b50d8_row1_col6" class="data row1 col6" >0.023537</td>
#     </tr>
#     <tr>
#       <th id="T_b50d8_level0_row2" class="row_heading level0 row2" >NAT Source Port</th>
#       <td id="T_b50d8_row2_col0" class="data row2 col0" >0.145391</td>
#       <td id="T_b50d8_row2_col1" class="data row2 col1" >-0.281676</td>
#       <td id="T_b50d8_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b50d8_row2_col3" class="data row2 col3" >0.178435</td>
#       <td id="T_b50d8_row2_col4" class="data row2 col4" >0.002242</td>
#       <td id="T_b50d8_row2_col5" class="data row2 col5" >0.020827</td>
#       <td id="T_b50d8_row2_col6" class="data row2 col6" >0.141485</td>
#     </tr>
#     <tr>
#       <th id="T_b50d8_level0_row3" class="row_heading level0 row3" >NAT Destination Port</th>
#       <td id="T_b50d8_row3_col0" class="data row3 col0" >-0.024843</td>
#       <td id="T_b50d8_row3_col1" class="data row3 col1" >0.410042</td>
#       <td id="T_b50d8_row3_col2" class="data row3 col2" >0.178435</td>
#       <td id="T_b50d8_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b50d8_row3_col4" class="data row3 col4" >0.007904</td>
#       <td id="T_b50d8_row3_col5" class="data row3 col5" >-0.003216</td>
#       <td id="T_b50d8_row3_col6" class="data row3 col6" >0.219776</td>
#     </tr>
#     <tr>
#       <th id="T_b50d8_level0_row4" class="row_heading level0 row4" >Bytes Sent</th>
#       <td id="T_b50d8_row4_col0" class="data row4 col0" >-0.000931</td>
#       <td id="T_b50d8_row4_col1" class="data row4 col1" >0.001675</td>
#       <td id="T_b50d8_row4_col2" class="data row4 col2" >0.002242</td>
#       <td id="T_b50d8_row4_col3" class="data row4 col3" >0.007904</td>
#       <td id="T_b50d8_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_b50d8_row4_col5" class="data row4 col5" >0.575047</td>
#       <td id="T_b50d8_row4_col6" class="data row4 col6" >0.126039</td>
#     </tr>
#     <tr>
#       <th id="T_b50d8_level0_row5" class="row_heading level0 row5" >Bytes Received</th>
#       <td id="T_b50d8_row5_col0" class="data row5 col0" >0.001950</td>
#       <td id="T_b50d8_row5_col1" class="data row5 col1" >-0.014684</td>
#       <td id="T_b50d8_row5_col2" class="data row5 col2" >0.020827</td>
#       <td id="T_b50d8_row5_col3" class="data row5 col3" >-0.003216</td>
#       <td id="T_b50d8_row5_col4" class="data row5 col4" >0.575047</td>
#       <td id="T_b50d8_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_b50d8_row5_col6" class="data row5 col6" >0.143601</td>
#     </tr>
#     <tr>
#       <th id="T_b50d8_level0_row6" class="row_heading level0 row6" >Elapsed Time (sec)</th>
#       <td id="T_b50d8_row6_col0" class="data row6 col0" >-0.046515</td>
#       <td id="T_b50d8_row6_col1" class="data row6 col1" >0.023537</td>
#       <td id="T_b50d8_row6_col2" class="data row6 col2" >0.141485</td>
#       <td id="T_b50d8_row6_col3" class="data row6 col3" >0.219776</td>
#       <td id="T_b50d8_row6_col4" class="data row6 col4" >0.126039</td>
#       <td id="T_b50d8_row6_col5" class="data row6 col5" >0.143601</td>
#       <td id="T_b50d8_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 欄位'Action'轉換為數值
LE = LabelEncoder()
temp = df2['Action']
df2['Action'] = LE.fit_transform(df2['Action'])
print (set(zip(temp,df2['Action'])))

df2['Action'].replace({2: 1, 3: 1}, inplace=True)
print (set(zip(temp,df2['Action'])))
# Out:
# {('allow', 0), ('reset-both', 3), ('deny', 1), ('drop', 2)}
# {('allow', 0), ('reset-both', 1), ('drop', 1), ('deny', 1)}

# %%
# 設定 X、Y
x = df2.loc[:,~df2.columns.isin(['Action'])]
y = df2.loc[:,df2.columns.isin(['Action'])]
# 共線性檢查-Variance Inflation Factor
VIF = pd.DataFrame(columns=['VIF'],index = x.columns)
VIF['VIF'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
VIF.style.applymap(lambda x : 'color : red' if x >= 10 else 'color : black')
# Out:
# <style type="text/css">
# #T_d008f_row0_col0, #T_d008f_row1_col0, #T_d008f_row2_col0, #T_d008f_row3_col0, #T_d008f_row4_col0, #T_d008f_row5_col0, #T_d008f_row6_col0 {
#   color: black;
# }
# </style>
# <table id="T_d008f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d008f_level0_col0" class="col_heading level0 col0" >VIF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d008f_level0_row0" class="row_heading level0 row0" >Source Port</th>
#       <td id="T_d008f_row0_col0" class="data row0 col0" >2.163898</td>
#     </tr>
#     <tr>
#       <th id="T_d008f_level0_row1" class="row_heading level0 row1" >Destination Port</th>
#       <td id="T_d008f_row1_col0" class="data row1 col0" >1.559872</td>
#     </tr>
#     <tr>
#       <th id="T_d008f_level0_row2" class="row_heading level0 row2" >NAT Source Port</th>
#       <td id="T_d008f_row2_col0" class="data row2 col0" >2.036032</td>
#     </tr>
#     <tr>
#       <th id="T_d008f_level0_row3" class="row_heading level0 row3" >NAT Destination Port</th>
#       <td id="T_d008f_row3_col0" class="data row3 col0" >1.474508</td>
#     </tr>
#     <tr>
#       <th id="T_d008f_level0_row4" class="row_heading level0 row4" >Bytes Sent</th>
#       <td id="T_d008f_row4_col0" class="data row4 col0" >1.498988</td>
#     </tr>
#     <tr>
#       <th id="T_d008f_level0_row5" class="row_heading level0 row5" >Bytes Received</th>
#       <td id="T_d008f_row5_col0" class="data row5 col0" >1.508764</td>
#     </tr>
#     <tr>
#       <th id="T_d008f_level0_row6" class="row_heading level0 row6" >Elapsed Time (sec)</th>
#       <td id="T_d008f_row6_col0" class="data row6 col0" >1.138570</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 建立訓練集、測試集
train_x, test_x , train_y, test_y = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
# LinearSVC
model = svm.LinearSVC(C=1)
model.fit(train_x,train_y)
print ('正確率：', model.score(test_x ,test_y))
pred_y = model.predict(test_x)
print(confusion_matrix(test_y , pred_y))
# Out:
# C:\Users\2022032803\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 正確率： 0.9846388606307223
# [[11071   259]
#  [   43  8287]]
# C:\Users\2022032803\Anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
# SVM_linear
model = svm.SVC(kernel = 'linear')
model.fit(train_x,train_y)
print ('正確率：', model.score(test_x ,test_y))
pred_y = model.predict(test_x)
print(confusion_matrix(test_y , pred_y))
# Out:
# C:\Users\2022032803\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 正確率： 0.9980162767039674
# [[11301    29]
#  [   10  8320]]

# %%
# SVM_rbf
model = svm.SVC(kernel = 'rbf')
model.fit(train_x,train_y)
print ('正確率：', model.score(test_x ,test_y))
pred_y = model.predict(test_x)
print(confusion_matrix(test_y , pred_y))
# Out:
# C:\Users\2022032803\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 正確率： 0.8891658189216683
# [[9155 2175]
#  [   4 8326]]

# %%
# SVM_poly
model = svm.SVC(kernel = 'poly')
model.fit(train_x,train_y)
print ('正確率：', model.score(test_x ,test_y))
pred_y = model.predict(test_x)
print(confusion_matrix(test_y , pred_y))
# Out:
# C:\Users\2022032803\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 正確率： 0.5762970498474059
# [[11330     0]
#  [ 8330     0]]
